# %%
import pandas as pd

# %%
df = pd.read_excel('/content/FPS_hw_1_df_1_bank_customer.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CustomerId             2000 non-null   int64
#  1   Gender                 2000 non-null   object
#  2   Age                    2000 non-null   float64
#  3   Geography              2000 non-null   object
#  4   Balance, Euro          2000 non-null   float64
#  5   EstimatedSalary, Euro  2000 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 93.9+ KB

# %%
# Средний возраст
df['Age'].mean()
# Out:
# 39.34976408886279

# %%
# Стандартное отклонение
df['Age'].std()
# Out:
# 10.8106969987323

# %%
# Минимум
df['Age'].min()
# Out:
# 7.282502961178508

# %%
# Квантили
print('25-ый процентиль: ', df['Age'].quantile(0.25))
print('50-ый процентиль: ', df['Age'].quantile(0.50))
print('75-ый процентиль: ', df['Age'].quantile(0.75))
# Out:
# 25-ый квантиль:  31.915588073445644
# 50-ый квантиль:  39.26823927132854
# 75-ый квантиль:  46.73693538664487

# %%
# Максимум
df['Age'].max()
# Out:
# 86.99251839355286

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'], 20)
plt.title('Распределение возраста')
plt.xlabel('Возраст')
# Распределение близкое  к нормальному
# Out:
# Text(0.5, 0, 'Возраст')
