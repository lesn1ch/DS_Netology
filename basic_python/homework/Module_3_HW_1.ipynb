# %% [markdown]
# # Задание 1
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.

# %%
# TASK 1
phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

if len(phrase_1) == len(phrase_2):
  print('Фразы равной длины')
elif len(phrase_1) > len(phrase_2):
  print('Фраза 1 длиннее фразы 2')
else:
  print('Фраза 2 длиннее фразы 1')

# %% [markdown]
# # Задание 2
# Дана переменная, в которой хранится число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.

# %%
# TASK 2
year = 2020
if year % 4 == 0:
  print('Високосный год')
else:
  print('Обычный год')

# %% [markdown]
# # Задание 3
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# TASK 3
zodiac_table = {
    ('03-21', '04-20'): 'Овен',
    ('04-21', '05-21'): 'Телец',
    ('05-21', '06-21'): 'Близнецы',
    ('06-22', '07-22'): 'Рак',
    ('07-23', '07-23'): 'Лев',
    ('08-24', '09-23'): 'Дева',
    ('09-24', '10-23'): 'Весы',
    ('10-24', '11-22'): 'Скорпион',
    ('11-23', '12-21'): 'Стрелец',
    ('12-22', '12-31'): 'Козерог',
    ('01-01', '01-20'): 'Козерог',
    ('01-21', '02-18'): 'Водолей',
    ('02-19', '03-20'): 'Рыбы',
}

month_tbl = {
    'январь': '01',
    'февраль': '02',
    'март': '03',
    'апрель': '04',
    'май': '05',
    'июнь': '06',
    'июль': '07',
    'август': '08',
    'сентябрь': '09',
    'октябрь': '10',
    'ноябрь': '11',
    'декабрь': '12'
}
day_tmp = int(input('Введите день:'))
day = str(day_tmp) if day_tmp in range(10, 32) else f'0{day_tmp}'
month = input('Введите месяц:').lower()

user_dt = month_tbl[month] + '-' + day

for key in zodiac_table:
  if key[0] <= user_dt <= key[1]:
    print(zodiac_table[key])
# Out:
# Введите день:4
# Введите месяц:май

# %% [markdown]
# # Задание 4
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):
#
# Используйте следующие правила:
#
# * если каждое из трех измерений менее или равно 15 сантиметрам, то выведите на экран "Коробка №1";
# * если хотя бы одно из измерений больше 2 метров, то выводите "Упаковка для лыж";
# * если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
# * во всех остальных случаях выводите "Коробка №3"

# %%
# TASK 4
width = 15
length = 99
height = 15

if all([width <= 15, length <= 15, height <= 15]):
  print('Коробка №1')
elif any([width > 200, length > 200, height > 200]):
  print('Коробка для лыж')
elif any([15 < width < 50, 15 < length < 50, 15 < height < 50]):
  print('Коробка №2')
else:
  print('Коробка №3')
# Out:
# Коробка №3

# %% [markdown]
# # Задание 5
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет "счастливым". Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.

# %%
# TASK 5*
num = 100343
# Если у нас гарантировано, что номер не начинается с 0
sum_1 = num % 10 + num // 10 % 10 + num // 100 % 10
sum_2 = num // 1000 % 10 + num // 10000 % 10 + num // 100000 % 10

# Если не гарантировано, что номер не начинается с 0
# num = '001010'
# sum_1 = int(num[0]) + int(num[1]) + int(num[2])
# sum_2 = int(num[3]) + int(num[4]) + int(num[5])
if sum_1 == sum_2:
  print('You win!')
else:
  print('Not today!')
# Out:
# You win!
